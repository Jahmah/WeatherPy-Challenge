# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy


# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 635

# %% [markdown]
# ## Perform API Calls

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key + "&q="

# set up lists to hold reponse info
lat = []
temp = []
city_name = []
country = []
humidity = []
cloudiness = []
windspeed = []


# Loop through the list of cities and perform a request for data on each
print("Data Retrieval")

row_count = 0

for city in cities:
    query_url = url  + city
    response = requests.get(query_url).json()
    if response["cod"] == "404":
        print("No city record found. Skipping....")
    
    else:
        lat.append(response['coord']['lat'])
        temp.append(response['main']['temp'])
        city_name.append(response['name'])
        country.append(response['sys']['country'])
        humidity.append(response['main']['humidity'])
        windspeed.append(response['wind']['speed'])
        cloudiness.append(response['clouds']['all'])
    
    
    print("---------------------------------------------------")
    try:
        print("Proceesing: Record # " , row_count, ' | ' , response["name"], response['sys']['country'],'|' , response["id"])
        print(query_url)
    except KeyError: 
        print("Proceesing: Record # " , row_count, ' | ' , " City name not found on server")
        print(query_url)
        
    
    row_count += 1
    
print("---------------------------------------------------")    
print("Data Retrieval Complete")
print("---------------------------------------------------")
# Out:
# Data Retrieval
# ---------------------------------------------------
# Proceesing: Record #  0  |  Tari NG | 2322495
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=tari
# ---------------------------------------------------
# Proceesing: Record #  1  |  Busselton AU | 2075265
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=busselton
# ---------------------------------------------------
# Proceesing: Record #  2  |  Bambous Virieux MU | 1106677
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=bambous virieux
# ---------------------------------------------------
# Proceesing: Record #  3  |  Samarai PG | 2132606
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=samarai
# ---------------------------------------------------
# Proceesing: Record #  4  |  Rikitea PF | 4030556
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=rikitea
# ---------------------------------------------------
# Proceesing: Record #  5  |  Mar del Plata AR | 3863379
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=mar del plata
# ---------------------------------------------------
# Proceesing: Record #  6  |  Udachnyy RU | 2014624
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=udachnyy
# ---------------------------------------------------
# Proceesing: Record #  7  |  Souillac FR | 3026644
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=souillac
# ---------------------------------------------------
# Proceesing: Record #  8  |  Salalah OM | 286621
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=salalah
# ---------------------------------------------------
# Proceesing: Record #  9  |  Talnakh RU | 1490256
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=talnakh
# ---------------------------------------------------
# Proceesing: Record #  10  |  Punta Arenas CL | 3874787
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=punta arenas
# ---------------------------------------------------
# Proceesing: Record #  11  |  Mataura NZ | 6201424
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=mataura
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  12  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=sataua
# ---------------------------------------------------
# Proceesing: Record #  13  |  Shache CN | 1280037
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=shache
# ---------------------------------------------------
# Proceesing: Record #  14  |  Vaini IN | 1273574
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=vaini
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  15  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=grand river south east
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  16  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=sentyabrskiy
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  17  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=tsihombe
# ---------------------------------------------------
# Proceesing: Record #  18  |  Santa Isabel do Rio Negro BR | 3662489
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=santa isabel do rio negro
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  19  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=illoqqortoormiut
# ---------------------------------------------------
# Proceesing: Record #  20  |  Yanam IN | 1252795
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=yanam
# ---------------------------------------------------
# Proceesing: Record #  21  |  Khatanga RU | 2022572
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=khatanga
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  22  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=amderma
# ---------------------------------------------------
# Proceesing: Record #  23  |  Barcelona ES | 3128760
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=barcelona
# ---------------------------------------------------
# Proceesing: Record #  24  |  Namatanai PG | 2090021
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=namatanai
# ---------------------------------------------------
# Proceesing: Record #  25  |  Albany US | 5106834
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=albany
# ---------------------------------------------------
# Proceesing: Record #  26  |  Husavik CA | 5961417
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=husavik
# ---------------------------------------------------
# Proceesing: Record #  27  |  Leningradskiy RU | 2123814
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=leningradskiy
# ---------------------------------------------------
# Proceesing: Record #  28  |  Ushuaia AR | 3833367
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=ushuaia
# ---------------------------------------------------
# Proceesing: Record #  29  |  Nikolskoye RU | 546105
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=nikolskoye
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  30  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=tumannyy
# ---------------------------------------------------
# Proceesing: Record #  31  |  Krasnyy Chikoy RU | 2012349
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=krasnyy chikoy
# ---------------------------------------------------
# Proceesing: Record #  32  |  Luwuk ID | 1637001
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=luwuk
# ---------------------------------------------------
# Proceesing: Record #  33  |  Hunsur IN | 1269873
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=hunsur
# ---------------------------------------------------
# Proceesing: Record #  34  |  Port Elizabeth US | 4501427
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=port elizabeth
# ---------------------------------------------------
# Proceesing: Record #  35  |  Huilong CN | 1795424
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=huilong
# ---------------------------------------------------
# Proceesing: Record #  36  |  Salair RU | 1493224
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=salair
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  37  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=satitoa
# ---------------------------------------------------
# Proceesing: Record #  38  |  Puerto Ayora EC | 3652764
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=puerto ayora
# ---------------------------------------------------
# Proceesing: Record #  39  |  Norman Wells CA | 6089245
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=norman wells
# ---------------------------------------------------
# Proceesing: Record #  40  |  Ban Mo TH | 1608900
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=ban mo
# ---------------------------------------------------
# Proceesing: Record #  41  |  Arraial do Cabo BR | 3471451
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=arraial do cabo
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  42  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=attawapiskat
# ---------------------------------------------------
# Proceesing: Record #  43  |  Alice Springs AU | 2077895
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=alice springs
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  44  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=ye
# ---------------------------------------------------
# Proceesing: Record #  45  |  El Retorno CO | 3792387
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=el retorno
# ---------------------------------------------------
# Proceesing: Record #  46  |  Castro CL | 3896218
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=castro
# ---------------------------------------------------
# Proceesing: Record #  47  |  Clyde River CA | 5924351
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=clyde river
# ---------------------------------------------------
# Proceesing: Record #  48  |  Jamestown AU | 2069194
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=jamestown
# ---------------------------------------------------
# Proceesing: Record #  49  |  Anzio IT | 6542092
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=anzio
# ---------------------------------------------------
# Proceesing: Record #  50  |  Provideniya RU | 4031574
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=provideniya
# ---------------------------------------------------
# Proceesing: Record #  51  |  Qaanaaq GL | 3831208
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=qaanaaq
# ---------------------------------------------------
# Proceesing: Record #  52  |  Lewistown US | 4899665
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=lewistown
# ---------------------------------------------------
# Proceesing: Record #  53  |  Barrow AR | 3833859
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=barrow
# ---------------------------------------------------
# Proceesing: Record #  54  |  Puerto Escondido MX | 3520994
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=puerto escondido
# ---------------------------------------------------
# Proceesing: Record #  55  |  Mehran IR | 124291
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=mehran
# ---------------------------------------------------
# Proceesing: Record #  56  |  Bluff AU | 2175403
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=bluff
# ---------------------------------------------------
# Proceesing: Record #  57  |  Hovd NO | 7626384
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=hovd
# ---------------------------------------------------
# Proceesing: Record #  58  |  Yulara AU | 6355222
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=yulara
# ---------------------------------------------------
# Proceesing: Record #  59  |  Luderitz NA | 3355672
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=luderitz
# ---------------------------------------------------
# Proceesing: Record #  60  |  Cairns AU | 2172797
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=cairns
# ---------------------------------------------------
# Proceesing: Record #  61  |  Poum MK | 787487
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=poum
# ---------------------------------------------------
# Proceesing: Record #  62  |  Fortuna ES | 2517679
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=fortuna
# ---------------------------------------------------
# Proceesing: Record #  63  |  Port Alfred ZA | 964432
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=port alfred
# ---------------------------------------------------
# Proceesing: Record #  64  |  Cururupu BR | 3401148
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=cururupu
# ---------------------------------------------------
# Proceesing: Record #  65  |  Severo-Kurilsk RU | 2121385
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=severo-kurilsk
# ---------------------------------------------------
# Proceesing: Record #  66  |  Atuona PF | 4020109
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=atuona
# ---------------------------------------------------
# Proceesing: Record #  67  |  Bathsheba BB | 3374083
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=bathsheba
# ---------------------------------------------------
# Proceesing: Record #  68  |  Ribeira Grande PT | 3372707
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=ribeira grande
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  69  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=vaitupu
# ---------------------------------------------------
# Proceesing: Record #  70  |  Hilo US | 5855927
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=hilo
# ---------------------------------------------------
# Proceesing: Record #  71  |  Chuy UY | 3443061
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=chuy
# ---------------------------------------------------
# Proceesing: Record #  72  |  Kavaratti IN | 1267390
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=kavaratti
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  73  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=ardistan
# ---------------------------------------------------
# Proceesing: Record #  74  |  Port-Gentil GA | 2396518
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=port-gentil
# ---------------------------------------------------
# Proceesing: Record #  75  |  Henties Bay NA | 3356832
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=henties bay
# ---------------------------------------------------
# Proceesing: Record #  76  |  Byron Bay AU | 2172880
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=byron bay
# ---------------------------------------------------
# Proceesing: Record #  77  |  Saint-Philippe CA | 6138908
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=saint-philippe
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  78  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=urumqi
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  79  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=bac lieu
# ---------------------------------------------------
# Proceesing: Record #  80  |  Vylkove UA | 688750
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=vylkove
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  81  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=longlac
# ---------------------------------------------------
# Proceesing: Record #  82  |  Aswan EG | 359792
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=aswan
# ---------------------------------------------------
# Proceesing: Record #  83  |  Ures MX | 3971596
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=ures
# ---------------------------------------------------
# Proceesing: Record #  84  |  Lebu ET | 344979
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=lebu
# ---------------------------------------------------
# Proceesing: Record #  85  |  Hermanus ZA | 3366880
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=hermanus
# ---------------------------------------------------
# Proceesing: Record #  86  |  Mandurah AU | 2067119
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=mandurah
# ---------------------------------------------------
# Proceesing: Record #  87  |  Lagoa PT | 2267254
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=lagoa
# ---------------------------------------------------
# Proceesing: Record #  88  |  Adrar DZ | 2508813
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=adrar
# ---------------------------------------------------
# Proceesing: Record #  89  |  Koppies ZA | 987875
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=koppies
# ---------------------------------------------------
# Proceesing: Record #  90  |  Pangoa PE | 3933104
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=pangoa
# ---------------------------------------------------
# Proceesing: Record #  91  |  Mahebourg MU | 934322
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=mahebourg
# ---------------------------------------------------
# Proceesing: Record #  92  |  Powassan CA | 6112530
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=powassan
# ---------------------------------------------------
# Proceesing: Record #  93  |  Ponta Pora BR | 3453150
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=ponta pora
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  94  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=belushya guba
# ---------------------------------------------------
# Proceesing: Record #  95  |  Nepa Nagar IN | 1261517
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=nepa nagar
# ---------------------------------------------------
# Proceesing: Record #  96  |  Paka HR | 3190586
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=paka
# ---------------------------------------------------
# Proceesing: Record #  97  |  Cape Town ZA | 3369157
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=cape town
# ---------------------------------------------------
# Proceesing: Record #  98  |  Beringovskiy RU | 2126710
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=beringovskiy
# ---------------------------------------------------
# Proceesing: Record #  99  |  Langsa ID | 1214724
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=langsa
# ---------------------------------------------------
# Proceesing: Record #  100  |  Djougou BJ | 2394560
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=djougou
# ---------------------------------------------------
# Proceesing: Record #  101  |  Rio Gallegos AR | 3838859
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=rio gallegos
# ---------------------------------------------------
# Proceesing: Record #  102  |  Pevek RU | 2122090
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=pevek
# ---------------------------------------------------
# Proceesing: Record #  103  |  Tumut AU | 2145875
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=tumut
# ---------------------------------------------------
# Proceesing: Record #  104  |  Alyangula AU | 2079582
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=alyangula
# ---------------------------------------------------
# Proceesing: Record #  105  |  Victoria BN | 1733782
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=victoria
# ---------------------------------------------------
# Proceesing: Record #  106  |  Narimanov RU | 523443
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=narimanov
# ---------------------------------------------------
# Proceesing: Record #  107  |  Yellowknife CA | 6185377
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=yellowknife
# ---------------------------------------------------
# Proceesing: Record #  108  |  Ingham AU | 2162737
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=ingham
# ---------------------------------------------------
# Proceesing: Record #  109  |  Santa Barbara US | 5392952
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=santa barbara
# ---------------------------------------------------
# Proceesing: Record #  110  |  Ahipara NZ | 2194098
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=ahipara
# ---------------------------------------------------
# Proceesing: Record #  111  |  Flinders AU | 6255012
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=flinders
# ---------------------------------------------------
# Proceesing: Record #  112  |  Kaitangata NZ | 2208248
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=kaitangata
# ---------------------------------------------------
# Proceesing: Record #  113  |  Katsuura JP | 1865309
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=katsuura
# ---------------------------------------------------
# Proceesing: Record #  114  |  Ponta do Sol BR | 3453439
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=ponta do sol
# ---------------------------------------------------
# Proceesing: Record #  115  |  Kapaa US | 5848280
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=kapaa
# ---------------------------------------------------
# Proceesing: Record #  116  |  Teya MX | 3526662
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=teya
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  117  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=karakendzha
# ---------------------------------------------------
# Proceesing: Record #  118  |  Carnarvon ZA | 1014034
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=carnarvon
# ---------------------------------------------------
# Proceesing: Record #  119  |  Carlsbad CZ | 3339539
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=carlsbad
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  120  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=nam tha
# ---------------------------------------------------
# Proceesing: Record #  121  |  Puerto Colombia CO | 3671497
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=puerto colombia
# ---------------------------------------------------
# Proceesing: Record #  122  |  Klerksdorp ZA | 989921
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=klerksdorp
# ---------------------------------------------------
# Proceesing: Record #  123  |  Marsh Harbour BS | 3571913
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=marsh harbour
# ---------------------------------------------------
# Proceesing: Record #  124  |  Thompson CA | 6165406
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=thompson
# ---------------------------------------------------
# Proceesing: Record #  125  |  Puri ID | 1635111
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=puri
# ---------------------------------------------------
# Proceesing: Record #  126  |  Aklavik CA | 5882953
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=aklavik
# ---------------------------------------------------
# Proceesing: Record #  127  |  College US | 5859699
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=college
# ---------------------------------------------------
# Proceesing: Record #  128  |  Clinton US | 4852022
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=clinton
# ---------------------------------------------------
# Proceesing: Record #  129  |  Havre US | 5656497
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=havre
# ---------------------------------------------------
# Proceesing: Record #  130  |  North Platte US | 5697939
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=north platte
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  131  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=tarudant
# ---------------------------------------------------
# Proceesing: Record #  132  |  Bubaque GW | 2374583
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=bubaque
# ---------------------------------------------------
# Proceesing: Record #  133  |  Mayo CA | 6068416
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=mayo
# ---------------------------------------------------
# Proceesing: Record #  134  |  Srednekolymsk RU | 2121025
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=srednekolymsk
# ---------------------------------------------------
# Proceesing: Record #  135  |  Grand Gaube MU | 934479
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=grand gaube
# ---------------------------------------------------
# Proceesing: Record #  136  |  Kaduna NG | 2335727
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=kaduna
# ---------------------------------------------------
# Proceesing: Record #  137  |  Georgetown GY | 3378644
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=georgetown
# ---------------------------------------------------
# Proceesing: Record #  138  |  Murgud IN | 1262435
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=murgud
# ---------------------------------------------------
# Proceesing: Record #  139  |  Jiehu CN | 1805884
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=jiehu
# ---------------------------------------------------
# Proceesing: Record #  140  |  Bintulu MY | 1737486
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=bintulu
# ---------------------------------------------------
# Proceesing: Record #  141  |  Maragogi BR | 3395458
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=maragogi
# ---------------------------------------------------
# Proceesing: Record #  142  |  Hithadhoo MV | 1282256
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=hithadhoo
# ---------------------------------------------------
# Proceesing: Record #  143  |  North Bend US | 5742974
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=north bend
# ---------------------------------------------------
# Proceesing: Record #  144  |  Hobart AU | 2163355
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=hobart
# ---------------------------------------------------
# Proceesing: Record #  145  |  Salta AR | 3838233
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=salta
# ---------------------------------------------------
# Proceesing: Record #  146  |  Kinablangan PH | 1708743
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=kinablangan
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  147  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=taolanaro
# ---------------------------------------------------
# Proceesing: Record #  148  |  Sept-Iles CA | 6144312
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=sept-iles
# ---------------------------------------------------
# Proceesing: Record #  149  |  Lata IN | 1253628
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=lata
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  150  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=rungata
# ---------------------------------------------------
# Proceesing: Record #  151  |  Vardo US | 4372777
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=vardo
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  152  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=tawkar
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  153  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=marcona
# ---------------------------------------------------
# Proceesing: Record #  154  |  Dikson RU | 1507390
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=dikson
# ---------------------------------------------------
# Proceesing: Record #  155  |  Loukhi RU | 533964
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=loukhi
# ---------------------------------------------------
# Proceesing: Record #  156  |  Pokhara NP | 1282898
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=pokhara
# ---------------------------------------------------
# Proceesing: Record #  157  |  Bandarbeyla SO | 64814
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=bandarbeyla
# ---------------------------------------------------
# Proceesing: Record #  158  |  Smithers CA | 6149996
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=smithers
# ---------------------------------------------------
# Proceesing: Record #  159  |  Tokur RU | 2015217
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=tokur
# ---------------------------------------------------
# Proceesing: Record #  160  |  Torbay CA | 6167817
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=torbay
# ---------------------------------------------------
# Proceesing: Record #  161  |  Severomuysk RU | 2016907
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=severomuysk
# ---------------------------------------------------
# Proceesing: Record #  162  |  Lavrentiya RU | 4031637
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=lavrentiya
# ---------------------------------------------------
# Proceesing: Record #  163  |  Prince Rupert CA | 6113406
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=prince rupert
# ---------------------------------------------------
# Proceesing: Record #  164  |  Kamenka RU | 553725
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=kamenka
# ---------------------------------------------------
# Proceesing: Record #  165  |  Killybegs IE | 2963295
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=killybegs
# ---------------------------------------------------
# Proceesing: Record #  166  |  Shingu JP | 1847947
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=shingu
# ---------------------------------------------------
# Proceesing: Record #  167  |  Weligama LK | 1223738
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=weligama
# ---------------------------------------------------
# Proceesing: Record #  168  |  Longyearbyen NO | 2729907
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=longyearbyen
# ---------------------------------------------------
# Proceesing: Record #  169  |  Vila Franca do Campo PT | 3372472
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=vila franca do campo
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  170  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=ahumada
# ---------------------------------------------------
# Proceesing: Record #  171  |  New Norfolk AU | 2155415
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=new norfolk
# ---------------------------------------------------
# Proceesing: Record #  172  |  Alofi NU | 4036284
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=alofi
# ---------------------------------------------------
# Proceesing: Record #  173  |  Tottori JP | 1849892
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=tottori
# ---------------------------------------------------
# Proceesing: Record #  174  |  Tuktoyaktuk CA | 6170031
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=tuktoyaktuk
# ---------------------------------------------------
# Proceesing: Record #  175  |  Alto Araguaia BR | 3472473
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=alto araguaia
# ---------------------------------------------------
# Proceesing: Record #  176  |  Gushikawa JP | 1863495
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=gushikawa
# ---------------------------------------------------
# Proceesing: Record #  177  |  Araouane ML | 2460954
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=araouane
# ---------------------------------------------------
# Proceesing: Record #  178  |  Kieta PG | 2094027
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=kieta
# ---------------------------------------------------
# Proceesing: Record #  179  |  Sorland NO | 3137469
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=sorland
# ---------------------------------------------------
# Proceesing: Record #  180  |  East London ZA | 1006984
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=east london
# ---------------------------------------------------
# Proceesing: Record #  181  |  Portland US | 5746545
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=portland
# ---------------------------------------------------
# Proceesing: Record #  182  |  Alekseyevskaya RU | 582817
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=alekseyevskaya
# ---------------------------------------------------
# Proceesing: Record #  183  |  Monrovia LR | 2274895
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=monrovia
# ---------------------------------------------------
# Proceesing: Record #  184  |  Riacho de Santana BR | 3451448
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=riacho de santana
# ---------------------------------------------------
# Proceesing: Record #  185  |  Sao Felix do Xingu BR | 3388847
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=sao felix do xingu
# ---------------------------------------------------
# Proceesing: Record #  186  |  Eregli TR | 315498
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=eregli
# ---------------------------------------------------
# Proceesing: Record #  187  |  Butaritari KI | 2110227
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=butaritari
# ---------------------------------------------------
# Proceesing: Record #  188  |  Tasiilaq GL | 3424607
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=tasiilaq
# ---------------------------------------------------
# Proceesing: Record #  189  |  Manthani IN | 1263610
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=manthani
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  190  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=bengkulu
# ---------------------------------------------------
# Proceesing: Record #  191  |  Bredasdorp ZA | 1015776
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=bredasdorp
# ---------------------------------------------------
# Proceesing: Record #  192  |  Lorengau PG | 2092164
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=lorengau
# ---------------------------------------------------
# Proceesing: Record #  193  |  Cidreira BR | 3466165
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=cidreira
# ---------------------------------------------------
# Proceesing: Record #  194  |  Brits ZA | 1015621
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=brits
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  195  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=koboldo
# ---------------------------------------------------
# Proceesing: Record #  196  |  Niquelandia BR | 3456285
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=niquelandia
# ---------------------------------------------------
# Proceesing: Record #  197  |  Roebourne AU | 2062276
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=roebourne
# ---------------------------------------------------
# Proceesing: Record #  198  |  Isla Vista US | 5359864
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=isla vista
# ---------------------------------------------------
# Proceesing: Record #  199  |  Hasaki JP | 2112802
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=hasaki
# ---------------------------------------------------
# Proceesing: Record #  200  |  Mlonggo ID | 1635164
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=mlonggo
# ---------------------------------------------------
# Proceesing: Record #  201  |  Mgandu TZ | 154097
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=mgandu
# ---------------------------------------------------
# Proceesing: Record #  202  |  Poso ID | 1630723
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=poso
# ---------------------------------------------------
# Proceesing: Record #  203  |  Cooma AU | 2170577
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=cooma
# ---------------------------------------------------
# Proceesing: Record #  204  |  Tromso NO | 3133895
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=tromso
# ---------------------------------------------------
# Proceesing: Record #  205  |  Cherskiy RU | 2126199
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=cherskiy
# ---------------------------------------------------
# Proceesing: Record #  206  |  Rawson AR | 3839307
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=rawson
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  207  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=akyab
# ---------------------------------------------------
# Proceesing: Record #  208  |  Lasa CY | 146639
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=lasa
# ---------------------------------------------------
# Proceesing: Record #  209  |  Upernavik GL | 3418910
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=upernavik
# ---------------------------------------------------
# Proceesing: Record #  210  |  Te Anau NZ | 2181625
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=te anau
# ---------------------------------------------------
# Proceesing: Record #  211  |  Mount Isa AU | 2065594
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=mount isa
# ---------------------------------------------------
# Proceesing: Record #  212  |  Maracas TT | 7521947
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=maracas
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  213  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=duz
# ---------------------------------------------------
# Proceesing: Record #  214  |  Lerwick GB | 2644605
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=lerwick
# ---------------------------------------------------
# Proceesing: Record #  215  |  Nagato JP | 1899102
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=nagato
# ---------------------------------------------------
# ...
# ---------------------------------------------------
# Proceesing: Record #  563  |  San Quintin PH | 1688687
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=san quintin
# ---------------------------------------------------
# Proceesing: Record #  564  |  Porciuncula BR | 3453010
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=porciuncula
# ---------------------------------------------------
# Proceesing: Record #  565  |  Tal DE | 2953415
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=tal
# ---------------------------------------------------
# Proceesing: Record #  566  |  Jumla NP | 1283285
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=jumla
# ---------------------------------------------------
# Proceesing: Record #  567  |  Moree AU | 2156927
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=moree
# ---------------------------------------------------
# Proceesing: Record #  568  |  Aras YE | 69559
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=aras
# ---------------------------------------------------
# Proceesing: Record #  569  |  Ermelo NL | 2756039
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=ermelo
# ---------------------------------------------------
# Proceesing: Record #  570  |  Bronnoysund NO | 3159954
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=bronnoysund
# ---------------------------------------------------
# Proceesing: Record #  571  |  Baherden TM | 162158
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=baherden
# ---------------------------------------------------
# Proceesing: Record #  572  |  Gat SN | 2249901
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=gat
# ---------------------------------------------------
# Proceesing: Record #  573  |  Minot US | 5690532
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=minot
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  574  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=assela
# ---------------------------------------------------
# Proceesing: Record #  575  |  Kudahuvadhoo MV | 1337607
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=kudahuvadhoo
# ---------------------------------------------------
# Proceesing: Record #  576  |  Tigil RU | 2120612
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=tigil
# ---------------------------------------------------
# Proceesing: Record #  577  |  General Pico AR | 3855075
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=general pico
# ---------------------------------------------------
# Proceesing: Record #  578  |  Ekhabi RU | 2122614
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=ekhabi
# ---------------------------------------------------
# Proceesing: Record #  579  |  Liepaja LV | 457954
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=liepaja
# ---------------------------------------------------
# Proceesing: Record #  580  |  Russell AR | 3844421
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=russell
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  581  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=alappuzha
# ---------------------------------------------------
# Proceesing: Record #  582  |  Naze NG | 2337542
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=naze
# ---------------------------------------------------
# Proceesing: Record #  583  |  Villa Carlos Paz AR | 3832791
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=villa carlos paz
# ---------------------------------------------------
# Proceesing: Record #  584  |  Verkhnevilyuysk RU | 2013639
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=verkhnevilyuysk
# ---------------------------------------------------
# Proceesing: Record #  585  |  Bahjoi IN | 1277808
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=bahjoi
# ---------------------------------------------------
# Proceesing: Record #  586  |  Anadyr RU | 2127202
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=anadyr
# ---------------------------------------------------
# Proceesing: Record #  587  |  Abu Samrah SY | 172515
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=abu samrah
# ---------------------------------------------------
# Proceesing: Record #  588  |  Komsomolskiy RU | 1486910
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=komsomolskiy
# ---------------------------------------------------
# Proceesing: Record #  589  |  Kahului US | 5847411
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=kahului
# ---------------------------------------------------
# Proceesing: Record #  590  |  Wuda CN | 1791325
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=wuda
# ---------------------------------------------------
# Proceesing: Record #  591  |  El Calvario CO | 3684770
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=el calvario
# ---------------------------------------------------
# Proceesing: Record #  592  |  Cotonou BJ | 2394819
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=cotonou
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  593  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=warqla
# ---------------------------------------------------
# Proceesing: Record #  594  |  Tual ID | 1623197
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=tual
# ---------------------------------------------------
# Proceesing: Record #  595  |  San Ramon NI | 3616584
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=san ramon
# ---------------------------------------------------
# Proceesing: Record #  596  |  Zilair RU | 462626
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=zilair
# ---------------------------------------------------
# Proceesing: Record #  597  |  Sarangani PH | 1687186
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=sarangani
# ---------------------------------------------------
# Proceesing: Record #  598  |  San Benito CO | 3685961
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=san benito
# ---------------------------------------------------
# Proceesing: Record #  599  |  Bagenalstown IE | 2966800
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=bagenalstown
# ---------------------------------------------------
# Proceesing: Record #  600  |  Touros BR | 3386213
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=touros
# ---------------------------------------------------
# Proceesing: Record #  601  |  Barabash RU | 2027142
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=barabash
# ---------------------------------------------------
# Proceesing: Record #  602  |  Paldiski EE | 589663
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=paldiski
# ---------------------------------------------------
# Proceesing: Record #  603  |  Mount Gambier AU | 2156643
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=mount gambier
# ---------------------------------------------------
# Proceesing: Record #  604  |  Aljezur PT | 2271968
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=aljezur
# ---------------------------------------------------
# Proceesing: Record #  605  |  Lubben DE | 2875625
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=lubben
# ---------------------------------------------------
# Proceesing: Record #  606  |  Nailsea GB | 2641913
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=nailsea
# ---------------------------------------------------
# Proceesing: Record #  607  |  Porto Walter BR | 3662761
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=porto walter
# ---------------------------------------------------
# Proceesing: Record #  608  |  Sebastian US | 4172372
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=sebastian
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  609  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=labutta
# ---------------------------------------------------
# Proceesing: Record #  610  |  Okhotsk RU | 2122605
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=okhotsk
# ---------------------------------------------------
# Proceesing: Record #  611  |  Lethem GY | 3379316
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=lethem
# ---------------------------------------------------
# Proceesing: Record #  612  |  Northam GB | 2641434
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=northam
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  613  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=karaul
# ---------------------------------------------------
# Proceesing: Record #  614  |  Ambatofinandrahana MG | 1083239
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=ambatofinandrahana
# ---------------------------------------------------
# Proceesing: Record #  615  |  Karratha AU | 6620339
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=karratha
# ---------------------------------------------------
# Proceesing: Record #  616  |  Narsaq GL | 3421719
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=narsaq
# ---------------------------------------------------
# Proceesing: Record #  617  |  Manggar ID | 1636426
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=manggar
# ---------------------------------------------------
# Proceesing: Record #  618  |  Sindi EE | 588673
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=sindi
# ---------------------------------------------------
# Proceesing: Record #  619  |  Lamar US | 5427957
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=lamar
# ---------------------------------------------------
# Proceesing: Record #  620  |  Salima MW | 924055
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=salima
# ---------------------------------------------------
# Proceesing: Record #  621  |  Sinnamary GF | 3380290
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=sinnamary
# ---------------------------------------------------
# Proceesing: Record #  622  |  Kargopol RU | 552465
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=kargopol
# ---------------------------------------------------
# Proceesing: Record #  623  |  Peniche PT | 2264923
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=peniche
# ---------------------------------------------------
# Proceesing: Record #  624  |  Guymon US | 5515743
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=guymon
# ---------------------------------------------------
# Proceesing: Record #  625  |  Boende CD | 218680
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=boende
# ---------------------------------------------------
# Proceesing: Record #  626  |  Ukiah US | 5404476
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=ukiah
# ---------------------------------------------------
# Proceesing: Record #  627  |  Banda Aceh ID | 1215502
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=banda aceh
# ---------------------------------------------------
# Proceesing: Record #  628  |  Petauke ZM | 899825
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=petauke
# ---------------------------------------------------
# Proceesing: Record #  629  |  Bowen AU | 2174444
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=bowen
# ---------------------------------------------------
# Proceesing: Record #  630  |  Inverell AU | 2162662
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=inverell
# ---------------------------------------------------
# Proceesing: Record #  631  |  Itarema BR | 3393692
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=itarema
# ---------------------------------------------------
# Proceesing: Record #  632  |  Paracuru BR | 3393115
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=paracuru
# No city record found. Skipping....
# ---------------------------------------------------
# Proceesing: Record #  633  |   City name not found on server
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=lolua
# ---------------------------------------------------
# Proceesing: Record #  634  |  Comodoro Rivadavia AR | 3860443
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ed585d7738ddcf631470fb88f392aa1b&q=comodoro rivadavia
# ---------------------------------------------------
# Data Retrieval Complete
# ---------------------------------------------------

# %%
# create a data frame from cities, lat, and temp
weather_dict = {
    "City": city_name,
    "Country": country,
    "Latitude": lat,
    "Temperature (F)": temp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "WindSpeed": windspeed
}

weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# City               564
# Country            564
# Latitude           564
# Temperature (F)    564
# Humidity           564
# Cloudiness         564
# WindSpeed          564
# dtype: int64

# %%
weather_data.head()

# %%
# Save data to a CSV file
weather_data.to_csv("WeatherPy_analysis/City_Data.csv")

# %%
#Set up variables for current date
now = time.localtime(time.time())
date = time.strftime("%m/%d/%y", now)

# %%
#Build a scatter plot for Latitude vs. Temperature

plt.scatter(weather_data["Latitude"], 
            weather_data["Temperature (F)"], c="blue",
            edgecolor="black", linewidths=1, marker="o",
             alpha=0.8, label="City")


# Incorporate the other graph properties
plt.title(f"City Latitude vs. Max Temperature ({date})")      
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-10, 130])


# Save the figure
plt.savefig("WeatherPy_analysis/Latitude_Temperature.png")

# Show plot
plt.show()

# %%
#Build a scatter plot for Latitude vs. Humidity

plt.scatter(weather_data["Latitude"], 
            weather_data["Humidity"], c="blue",
            edgecolor="black", linewidths=1, marker="o",
             alpha=0.8, label="City")


# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity ({date}")      
plt.ylabel(" Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-20, 120])


# Save the figure
plt.savefig("WeatherPy_analysis/Latitude_Humidity.png")

# Show plot
plt.show()

# %%
#Build a scatter plot for Latitude vs. Cloudiness

plt.scatter(weather_data["Latitude"], 
            weather_data["Cloudiness"], c="blue",
            edgecolor="black", linewidths=1, marker="o",
             alpha=0.8, label="City")


# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness  ({date})")      
plt.ylabel(" Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-20, 120])


# Save the figure
plt.savefig("WeatherPy_analysis/Latitude_Cloudiness.png")

# Show plot
plt.show()

# %%
#Build a scatter plot for Latitude vs. Windspeed

plt.scatter(weather_data["Latitude"], 
            weather_data["WindSpeed"], c="blue",
            edgecolor="black", linewidths=1, marker="o",
             alpha=0.8, label="City")


# Incorporate the other graph properties
plt.title(f"City Latitude vs. WindSpeed ({date}) ")      
plt.ylabel(" WindSpeed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
plt.xlim([-80, 100])
plt.ylim([-5, 40])


# Save the figure
plt.savefig("WeatherPy_analysis/Latitude_Windspeed.png")

# Show plot
plt.show()

# %% [markdown]
# # WeatherPy - Analysis:
#
#
# 1. Even though the dataset is based on a random and uniform distribution of generated coordinates, most of the cities from the data retrieval process lie in the northern hemishphere. This however correlates with the fact that 90% of the world population live in cities in the northern hemisphere.
#
#
# 2. The highest temperatures lie between latitudes -20 and 40 degrees. This confirms the fact that the closer you move to the Equator, which lies on latitude 0 degrees, the warmer it gets. Based on the data, the highest temperatures are in the northern hemishpere which currently is experiencing  its summer season. In stark contrast, the southern hemisphere is just beginning its winter season and temperatures will continue to dip as the months move along. As is the case, the plotted data shows that the lowest temperature among the generated records is in the southern hemisphere.
#
#
# 3. Humidity is a concentration of water vapor in the air. From the plotted data, there is almost no difference in humidity levels across the two hemispheres. Rather, most cities in the generated dataset are all currently experiencing 60% and above humidity levels. This signifies a lot of water vapor in the atmosphere which should result in increased precipation as is the case now across many places in Africa, Asia and North America.
